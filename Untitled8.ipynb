# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
A = np.array([[ 2.06147691, -1.],[ 1.85380598, -1.],[ 1.99565605,  -1.],[ 1.90014726 , -1.], [ 2.08965634, -1.]])[1:3]
b = np.array([ 100.14086138, 1016.6299087, 1353.20441252, 2721.57300007 ,  3174.08061004])[1:3]
A_ = np.linalg.inv(np.dot(A.T, A)).dot(A.T).dot(b)
print(ret)
print(A_)
# Out:
# (array([ -6671.19098273, -14325.19900136]), array([ 2376752.7555234]), 2, array([ 4.39022151,  0.07376583]))
# [ 2372.74823918  3381.98496613]

# %%
x = np.linspace(0, 5000, 100);
y1 = A[0, 0] * x - b[0]
y2 = A[1, 0] * x - b[1]
# y3 = A[2, 0] * x - b[2]
# y4 = A[3, 0] * x - b[3]
# y5 = A[4, 0] * x - b[4]
plt.figure(figsize = (10, 20))
plt.plot(x, y1)
plt.plot(x, y2)
# plt.plot(x, y3)
# plt.plot(x, y4)
# plt.plot(x, y5)
plt.scatter(A_[0], A_[1])

plt.show()

# %%
A = np.array([[ 2.06147691, -1.],[ 1.99565605,  -1.],[ 1.90014726 , -1.] ])
b = np.array([100.14086138, 1353.20441252, 2721.57300007 ])
A_ = np.linalg.inv(np.dot(A.T, A)).dot(A.T).dot(b)
print(ret)
print(A_)
# Out:
# (array([ -6671.19098273, -14325.19900136]), array([ 2376752.7555234]), 2, array([ 4.39022151,  0.07376583]))
# [-16110.90109269 -33384.02355994]

# %%
x = np.linspace(0, 3000, 100);
y1 = A[0, 0] * x - b[0]
y2 = A[1, 0] * x - b[1]
y3 = A[2, 0] * x - b[2]
plt.figure(figsize = (16, 20))
plt.plot(x, y1)
plt.plot(x, y2)
plt.plot(x, y3)
plt.scatter(A_[0], A_[1])

plt.show()
