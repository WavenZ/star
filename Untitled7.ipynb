# %%
% matplotlib inline
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
src = cv2.imread('-21.png', 0)
plt.figure(dpi = 150)
plt.imshow(src, cmap = 'gray')
plt.axis('off')
# Out:
# (-0.5, 887.5, 540.5, -0.5)
